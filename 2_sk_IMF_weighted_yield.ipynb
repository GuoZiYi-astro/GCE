# %%
from NuPyCEE import omega as o
from NuPyCEE import sygma as s
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ## The plot of the IMF-weighted yields

# %% [markdown]
# For OMEGA do not have this function, I will show this plot in sygma

# %%
s1=s.sygma(mgal=1.5e12,imf_type='kroupa')
s2=s.sygma(mgal=1.5e12,imf_type='salpeter')
# Out:
# SYGMA run in progress..
#    SYGMA run completed - Run time: 0.03s
# SYGMA run in progress..
#    SYGMA run completed - Run time: 0.03s

# %%
e='O-16'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted.pdf',bbox_inches='tight')

# %%
e='O-17'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted.pdf',bbox_inches='tight')

# %%
e='O-18'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted.pdf',bbox_inches='tight')

# %%
e='C-12'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted.pdf',bbox_inches='tight')

# %%
e='C-13'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted.pdf',bbox_inches='tight')

# %%
e='Mg'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted.pdf',bbox_inches='tight')

# %%
e='Ca'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted.pdf',bbox_inches='tight')

# %%
e='Ti'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted.pdf',bbox_inches='tight')

# %%
e='Si'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted.pdf',bbox_inches='tight')

# %%
e='N-15'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted.pdf',bbox_inches='tight')

# %%
e='N-14'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted.pdf',bbox_inches='tight')

# %%
e='Fe'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted.pdf',bbox_inches='tight')

# %%
s3=s.sygma(mgal=1.5e12,imf_type='kroupa',iniZ=0.001)
# Out:
# SYGMA run in progress..
#    SYGMA run completed - Run time: 0.03s

# %%
e='O-16'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF, iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_k.pdf',bbox_inches='tight')

# %%
e='O-17'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF, iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_k.pdf',bbox_inches='tight')

# %%
e='O-18'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF, iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_k.pdf',bbox_inches='tight')

# %%
e='C-12'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF, iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_k.pdf',bbox_inches='tight')

# %%
e='C-13'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF, iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_k.pdf',bbox_inches='tight')

# %%
e='Mg'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF, iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_k.pdf',bbox_inches='tight')

# %%
e='Ca'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF, iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_k.pdf',bbox_inches='tight')

# %%
e='Ti'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF, iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_k.pdf',bbox_inches='tight')

# %%
e='Si'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF, iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_k.pdf',bbox_inches='tight')

# %%
e='N-15'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF, iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_k.pdf',bbox_inches='tight')

# %%
e='N-14'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF, iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_k.pdf',bbox_inches='tight')

# %%
e='Fe'
s1.plot_mass_range_contributions(specie=e,label='Kroupa IMF',color='r')
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF, iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_k.pdf',bbox_inches='tight')

# %%
s4=s.sygma(mgal=1.5e12,imf_type='salpeter',iniZ=0.001)
# Out:
# SYGMA run in progress..
#    SYGMA run completed - Run time: 0.03s

# %%
e='O-16'
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_s.pdf',bbox_inches='tight')

# %%
e='O-17'
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_s.pdf',bbox_inches='tight')

# %%
e='O-18'
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_s.pdf',bbox_inches='tight')

# %%
e='C-12'
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_s.pdf',bbox_inches='tight')

# %%
e='C-13'
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_s.pdf',bbox_inches='tight')

# %%
e='Mg'
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_s.pdf',bbox_inches='tight')

# %%
e='Ca'
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_s.pdf',bbox_inches='tight')

# %%
e='Ti'
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_s.pdf',bbox_inches='tight')

# %%
e='Si'
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_s.pdf',bbox_inches='tight')

# %%
e='N-15'
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_s.pdf',bbox_inches='tight')

# %%
e='N-14'
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_s.pdf',bbox_inches='tight')

# %%
e='Fe'
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='r')
s2.plot_mass_range_contributions(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_s.pdf',bbox_inches='tight')

# %%
e='O-16'
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF,iniZ=0.001',color='r')
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_001.pdf',bbox_inches='tight')

# %%
e='O-17'
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF,iniZ=0.001',color='r')
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_001.pdf',bbox_inches='tight')

# %%
e='O-18'
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF,iniZ=0.001',color='r')
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_001.pdf',bbox_inches='tight')

# %%
e='C-12'
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF,iniZ=0.001',color='r')
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_001.pdf',bbox_inches='tight')

# %%
e='C-13'
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF,iniZ=0.001',color='r')
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_001.pdf',bbox_inches='tight')

# %%
e='Mg'
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF,iniZ=0.001',color='r')
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_001.pdf',bbox_inches='tight')

# %%
e='Ca'
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF,iniZ=0.001',color='r')
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_001.pdf',bbox_inches='tight')

# %%
e='Ti'
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF,iniZ=0.001',color='r')
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_001.pdf',bbox_inches='tight')

# %%
e='Si'
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF,iniZ=0.001',color='r')
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_001.pdf',bbox_inches='tight')

# %%
e='N-15'
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF,iniZ=0.001',color='r')
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_001.pdf',bbox_inches='tight')

# %%
e='N-14'
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF,iniZ=0.001',color='r')
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_001.pdf',bbox_inches='tight')

# %%
e='Fe'
s3.plot_mass_range_contributions(specie=e,label='Kroupa IMF,iniZ=0.001',color='r')
s4.plot_mass_range_contributions(specie=e,label='Salpeter IMF,iniZ=0.001',color='b')
plt.title(e+' IMF-weighted yield')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/IMF_weighted/'+e+'_IMF_weighted_001.pdf',bbox_inches='tight')
