# %%
from NuPyCEE import omega as o
from matplotlib import pyplot as plt
from NuPyCEE import sygma as s
import matplotlib
import numpy as np

# %%
o_l=o.omega(cte_sfr=1,mgal=1e10,nb_1a_per_m=1e-4)
o_m=o.omega(cte_sfr=1,mgal=1e10,nb_1a_per_m=1e-3)
o_h=o.omega(cte_sfr=1,mgal=1e10,nb_1a_per_m=1e-2)
# Out:
# OMEGA run in progress..
#    OMEGA run completed - Run time: 0.62s
# OMEGA run in progress..
#    OMEGA run completed - Run time: 0.58s
# OMEGA run in progress..
#    OMEGA run completed - Run time: 0.58s

# %%
y='[Fe/H]'
o_l.plot_spectro(yaxis=y,color='k',label='SN Ia ratio = 1e-4')
o_m.plot_spectro(yaxis=y,color='r',label='SN Ia ratio = 1e-3')
o_h.plot_spectro(yaxis=y,color='m',label='SN Ia ratio = 1e-2')

# %%
y='[Si/H]'
o_l.plot_spectro(yaxis=y,color='k',label='SN Ia ratio = 1e-4')
o_m.plot_spectro(yaxis=y,color='r',label='SN Ia ratio = 1e-3')
o_h.plot_spectro(yaxis=y,color='m',label='SN Ia ratio = 1e-2')

# %%
y='[Si/Fe]'
o_l.plot_spectro(yaxis=y,color='k',label='SN Ia ratio = 1e-4')
o_m.plot_spectro(yaxis=y,color='r',label='SN Ia ratio = 1e-3')
o_h.plot_spectro(yaxis=y,color='m',label='SN Ia ratio = 1e-2')

# %%
y='[Si/Fe]'
x='[Fe/H]'
o_l.plot_spectro(xaxis=x,yaxis=y,color='k',label='SN Ia ratio = 1e-4')
o_m.plot_spectro(xaxis=x,yaxis=y,color='r',label='SN Ia ratio = 1e-3')
o_h.plot_spectro(xaxis=x,yaxis=y,color='m',label='SN Ia ratio = 1e-2')

# %%
y='[Ca/Fe]'
x='[Fe/H]'
o_l.plot_spectro(xaxis=x,yaxis=y,color='k',label='SN Ia ratio = 1e-4')
o_m.plot_spectro(xaxis=x,yaxis=y,color='r',label='SN Ia ratio = 1e-3')
o_h.plot_spectro(xaxis=x,yaxis=y,color='m',label='SN Ia ratio = 1e-2')

# %%
y='[Mg/Fe]'
x='[Fe/H]'
o_l.plot_spectro(xaxis=x,yaxis=y,color='k',label='SN Ia ratio = 1e-4')
o_m.plot_spectro(xaxis=x,yaxis=y,color='r',label='SN Ia ratio = 1e-3')
o_h.plot_spectro(xaxis=x,yaxis=y,color='m',label='SN Ia ratio = 1e-2')

# %%
y='[Mg/Fe]'
o_l.plot_spectro(yaxis=y,color='k',label='SN Ia ratio = 1e-4')
o_m.plot_spectro(yaxis=y,color='r',label='SN Ia ratio = 1e-3')
o_h.plot_spectro(yaxis=y,color='m',label='SN Ia ratio = 1e-2')

# %%
y='[Mg/Fe]'
o_l.plot_spectro(yaxis=y,color='k',label='SN Ia ratio = 1e-4')
o_m.plot_spectro(yaxis=y,color='r',label='SN Ia ratio = 1e-3')
o_h.plot_spectro(yaxis=y,color='m',label='SN Ia ratio = 1e-2')
plt.ylim(-1,1)
# Out:
# (-1.0, 1.0)

# %%
def pltsn(o_n,color,label):
    xy_n_all=o_n.plot_mass(specie='Mg',source='all',return_x_y=True)
    xy_n_massive=o_l.plot_mass(specie='Mg',source='massive',return_x_y=True)
    xy_n_agb=o_l.plot_mass(specie='Mg',source='agb',return_x_y=True)
    n_all=np.array(xy_n_all[1])
    n_massive=np.array(xy_n_massive[1])
    n_agb=np.array(xy_n_agb[1])
    n_sn=n_all-n_massive-n_agb
    plt.plot(xy_n_all[0],n_sn,color=color,label=label)
    return 0


#def sn1a(all,massive,agb):
    n_all=np.array(all[1])
    n_massive=np.array(massive[1])
    n_agb=np.array(agb[1])
    return n_all-n_massive-n_agb

#xy_l_all=o_l.plot_mass(specie='Mg',source='all',return_x_y=True)
#xy_l_massive=o_l.plot_mass(specie='Mg',source='massive',return_x_y=True)
#xy_l_agb=o_l.plot_mass(specie='Mg',source='agb',return_x_y=True)

xy_l_sn=pltsn(o_l,'r','SN Ia ratio = 1e-4')
xy_m_sn=pltsn(o_m,'g','SN Ia ratio = 1e-3')
xy_h_sn=pltsn(o_h,'b','SN Ia ratio = 1e-2')

plt.legend(loc='center left', bbox_to_anchor=(1.01, 0.5), markerscale=0.8, fontsize=14)
plt.yscale('log')
plt.xscale('log')
#xy_nl_all=np.array(xy_l_all[1])
#xy_nl_massive=np.array(xy_l_massive[1])
#xy_nl_agb=np.array(xy_l_agb[1])
#xy_l_sn=xy_nl_all-xy_nl_massive-xy_nl_agb

#plt.plot(xy_l_all[0],xy_l_sn)
#plt.plot(xy_m_all[0],xy_m_sn)
#plt.plot(xy_h_all[0],xy_h_sn)
#o_m.plot_mass(specie='Mg',source='SN1a',color='r',shape='--',label='SN Ia ratio = 1e-3')
#o_h.plot_mass(specie='Mg',source='SN1a',color='m',shape='-.',label='SN Ia ratio = 1e-2')
