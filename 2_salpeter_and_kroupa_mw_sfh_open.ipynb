# %%
from NuPyCEE import omega as o
from NuPyCEE import sygma as s
from matplotlib import pyplot as plt
import numpy as np

# %%
o1=o.omega(galaxy='milky_way',imf_type='kroupa',DM_evolution=True)
o2=o.omega(galaxy='milky_way',imf_type='salpeter',DM_evolution=True)
# Out:
# OMEGA run in progress..
# ..Time refinement..
#    OMEGA run completed - Run time: 0.86s
# OMEGA run in progress..
# ..Time refinement..
#    OMEGA run completed - Run time: 0.86s

# %% [markdown]
# ## SFH --- How the SFR change with the time (they should be the same for these two models)

# %%
o1.plot_star_formation_rate(label='Kroupa IMF')
o2.plot_star_formation_rate(label='Salpeter IMF')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/SFH.pdf',bbox_inches='tight')

# %% [markdown]
# ## The plot of some isotopic ratios

# %% [markdown]
# For plot_iso_ratio, the default solar abundance is from iniab2.0E-02GN93.ppn in yield_tables/iniabu.

# %%
y='C-12/C-13'
o1.plot_iso_ratio(yaxis=y,color='r',label='Kroupa IMF')
o2.plot_iso_ratio(yaxis=y,color='b',label='Salpeter IMF')
plt.title(y)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/C-12_C-13.pdf',bbox_inches='tight')
# Out:
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])

# %%
y='C-12/C-13'
o1.plot_iso_ratio(yaxis=y,color='r',label='Kroupa IMF')
o2.plot_iso_ratio(yaxis=y,color='b',label='Salpeter IMF')
plt.title(y)
plt.ylim(100,6e2)

y_ticks=np.arange(100,600,100)
plt.yticks(y_ticks)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/C-12_C-13_zoom.pdf',bbox_inches='tight')
# Out:
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])

# %%
y='O-16/O-18'
o1.plot_iso_ratio(yaxis=y,color='r',label='Kroupa IMF')
o2.plot_iso_ratio(yaxis=y,color='b',label='Salpeter IMF')
plt.title(y)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/O-16_O-18.pdf',bbox_inches='tight')
# Out:
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])

# %%
y='O-16/O-18'
o1.plot_iso_ratio(yaxis=y,color='r',label='Kroupa IMF')
o2.plot_iso_ratio(yaxis=y,color='b',label='Salpeter IMF')
plt.title(y)
plt.ylim(8e2,3e3)

y_ticks=np.arange(800,3000,330)
plt.yticks(y_ticks)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/O-16_O-18_zoom.pdf',bbox_inches='tight')
# Out:
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])

# %%
y='O-16/O-17'
o1.plot_iso_ratio(yaxis=y,color='r',label='Kroupa IMF')
o2.plot_iso_ratio(yaxis=y,color='b',label='Salpeter IMF')
plt.title(y)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/O-16_O-17.pdf',bbox_inches='tight')
# Out:
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])

# %%
y='O-16/O-17'
o1.plot_iso_ratio(yaxis=y,color='r',label='Kroupa IMF')
o2.plot_iso_ratio(yaxis=y,color='b',label='Salpeter IMF')
plt.title(y)

y_ticks=np.arange(2000,2500,100)
plt.yticks(y_ticks)
plt.ylim(2e3,2.5e3)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/O-16_O-17_zoom.pdf',bbox_inches='tight')
# Out:
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])

# %% [markdown]
# ## The plots of the evolution of some elements mass

# %%
e='O'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_mass(specie=e,return_x_y=True)
o2_x,o2_y=o2.plot_mass(specie=e,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# 16507460.481013667
# 11708689.937016672

# %%
e='O'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' zoom')
plt.ylim(1e6,2e7)
plt.xlim(2e7,2e10)
plt.grid(which='minor')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'zoom.pdf',bbox_inches='tight')

# %%
e='Mg'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_mass(specie=e,return_x_y=True)
o2_x,o2_y=o2.plot_mass(specie=e,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# 971083.8963764041
# 563763.5540211515

# %%
e='Mg'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' zoom')
plt.ylim(1e5,2e6)
plt.xlim(1e8,2e10)
plt.grid(which='minor')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'zoom.pdf',bbox_inches='tight')

# %%
e='Ca'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_mass(specie=e,return_x_y=True)
o2_x,o2_y=o2.plot_mass(specie=e,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# 175274.91580970903
# 168587.39260441877

# %%
e='Ca'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' zoom')
plt.ylim(1e4,2e5)
plt.xlim(5e7,2e10)
plt.grid(which='minor')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'zoom.pdf',bbox_inches='tight')

# %%
e='Ti'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_mass(specie=e,return_x_y=True)
o2_x,o2_y=o2.plot_mass(specie=e,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# 10422.519267844464
# 9423.918561968905

# %%
e='Ti'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' zoom')
plt.ylim(1e3,2e4)
plt.xlim(2e7,2e10)
plt.grid(which='minor')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'zoom.pdf',bbox_inches='tight')

# %%
e='Si'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_mass(specie=e,return_x_y=True)
o2_x,o2_y=o2.plot_mass(specie=e,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# 2840142.5258513996
# 2389885.0137153207

# %%
e='Si'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' zoom')
plt.ylim(2e5,4e6)
plt.xlim(3e7,2e10)
plt.grid(which='minor')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'zoom.pdf',bbox_inches='tight')

# %%
e='C'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_mass(specie=e,return_x_y=True)
o2_x,o2_y=o2.plot_mass(specie=e,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# 7102668.524354309
# 4527629.730772481

# %%
e='C'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' zoom')
plt.ylim(2e5,1e7)
plt.xlim(2e7,2e10)
plt.grid(which='minor')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'zoom.pdf',bbox_inches='tight')

# %%
e='N'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_mass(specie=e,return_x_y=True)
o2_x,o2_y=o2.plot_mass(specie=e,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# 1719360.9690021025
# 733935.5196365938

# %%
e='N'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' zoom')
plt.ylim(1e5,2e6)
plt.xlim(1e8,2e10)
plt.grid(which='minor')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'zoom.pdf',bbox_inches='tight')

# %%
e='Fe'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_mass(specie=e,return_x_y=True)
o2_x,o2_y=o2.plot_mass(specie=e,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# 6292866.439344228
# 5216503.788447149

# %%
e='Fe'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' zoom')
plt.ylim(2e5,8e6)
plt.xlim(3e7,2e10)
plt.grid(which='minor')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'zoom.pdf',bbox_inches='tight')

# %% [markdown]
# ## The plots of the evolution of the abundance of some elements

# %%
e='O'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_abun.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -0.5069508532730864
# -0.6606878565890402

# %%
e='O'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-0.9,-0.4)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_abun_zoom.pdf',bbox_inches='tight')

# %%
e='Mg'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_abun.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -0.629101426578579
# -0.8698262249430422

# %%
e='Mg'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-1,-0.5)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_abun_zoom.pdf',bbox_inches='tight')

# %%
e='Ca'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_abun.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -0.3699861365625021
# -0.39144585237094853

# %%
e='Ca'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-0.7,-0.2)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_abun_zoom.pdf',bbox_inches='tight')

# %%
e='Ti'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_abun.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -0.332922251077739
# -0.3812284757829101

# %%
e='Ti'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-0.6,-0.2)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_abun_zoom.pdf',bbox_inches='tight')

# %%
e='Si'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_abun.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -0.19589097804754507
# -0.2754191492457765

# %%
e='Si'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-0.5,-0.1)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_abun_zoom.pdf',bbox_inches='tight')

# %%
e='C'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_abun.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -0.4285527270371432
# -0.6286684134409564

# %%
e='C'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-0.8,-0.3)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_abun_zoom.pdf',bbox_inches='tight')

# %%
e='N'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_abun.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -0.5312668739495301
# -0.9055410737033189

# %%
e='N'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-1.2,-0.4)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_abun_zoom.pdf',bbox_inches='tight')

# %%
e='Fe'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_abun.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -0.09903272090874493
# -0.1850667505907646

# %%
e='Fe'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-0.6,-0)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_abun_zoom.pdf',bbox_inches='tight')

# %% [markdown]
# ## The plot of the evolution of the ratio of some elements

# %%
e='O'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -0.4079181323643415
# -0.47562110599827545

# %%
e='O'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-0.5,-0.3)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe_zoom.pdf',bbox_inches='tight')

# %%
e='Mg'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -0.5300687056698341
# -0.6847594743522778

# %%
e='Mg'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-0.7,-0.4)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe_zoom.pdf',bbox_inches='tight')

# %%
e='Ca'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -0.27095341565375697
# -0.2063791017801837

# %%
e='Ca'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-0.3,-0.1)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe_zoom.pdf',bbox_inches='tight')

# %%
e='Ti'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -0.23388953016899405
# -0.19616172519214548

# %%
e='Ti'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-0.25,-0.05)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe_zoom.pdf',bbox_inches='tight')

# %%
e='Si'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -0.09685825713879986
# -0.09035239865501193

# %%
e='Si'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-0.1,0.05)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe_zoom.pdf',bbox_inches='tight')

# %% [markdown]
# ## The plot of the evolution of the ratio of the elements with [Fe/H]

# %%
e='O'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe_Fe_H.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
print('final ratio of'+abun+':')
print(o1_y[-1])
print(o2_y[-1])
print('final ratio of [Fe/H]:')
print(o1_x[-1])
print(o2_x[-1])
# Out:
# final ratio of[O/Fe]:
# -0.4079181323643415
# -0.47562110599827545
# final ratio of [Fe/H]:
# -0.09903272090874493
# -0.1850667505907646

# %%
e='O'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x+' zoom')
plt.ylim(-0.5,-0.2)
plt.xlim(-0.8,0)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe_Fe_H_zoom.pdf',bbox_inches='tight')

# %%
e='Mg'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe_Fe_H.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
print('final ratio of'+abun+':')
print(o1_y[-1])
print(o2_y[-1])
print('final ratio of [Fe/H]:')
print(o1_x[-1])
print(o2_x[-1])
# Out:
# final ratio of[Mg/Fe]:
# -0.5300687056698341
# -0.6847594743522778
# final ratio of [Fe/H]:
# -0.09903272090874493
# -0.1850667505907646

# %%
e='Mg'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x+' zoom')
plt.ylim(-0.7,-0.4)
plt.xlim(-0.6,0)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe_Fe_H_zoom.pdf',bbox_inches='tight')

# %%
e='Ca'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe_Fe_H.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
print('final ratio of'+abun+':')
print(o1_y[-1])
print(o2_y[-1])
print('final ratio of [Fe/H]:')
print(o1_x[-1])
print(o2_x[-1])
# Out:
# final ratio of[Ca/Fe]:
# -0.27095341565375697
# -0.2063791017801837
# final ratio of [Fe/H]:
# -0.09903272090874493
# -0.1850667505907646

# %%
e='Ca'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x+' zoom')
plt.ylim(-0.3,0.1)
plt.xlim(-1.5,0)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe_Fe_H_zoom.pdf',bbox_inches='tight')

# %%
e='Ti'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe_Fe_H.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
print('final ratio of'+abun+':')
print(o1_y[-1])
print(o2_y[-1])
print('final ratio of [Fe/H]:')
print(o1_x[-1])
print(o2_x[-1])
# Out:
# final ratio of[Ti/Fe]:
# -0.23388953016899405
# -0.19616172519214548
# final ratio of [Fe/H]:
# -0.09903272090874493
# -0.1850667505907646

# %%
e='Ti'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x+' zoom')
plt.ylim(-0.25,0.2)
plt.xlim(-3,0)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe_Fe_H_zoom.pdf',bbox_inches='tight')

# %%
e='Si'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe_Fe_H.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
print('final ratio of'+abun+':')
print(o1_y[-1])
print(o2_y[-1])
print('final ratio of [Fe/H]:')
print(o1_x[-1])
print(o2_x[-1])
# Out:
# final ratio of[Si/Fe]:
# -0.09685825713879986
# -0.09035239865501193
# final ratio of [Fe/H]:
# -0.09903272090874493
# -0.1850667505907646

# %%
e='Si'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x+' zoom')
plt.ylim(-0.1,0.1)
plt.xlim(-0.6z,0)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/2_sk_open/'+e+'_Fe_Fe_H_zoom.pdf',bbox_inches='tight')
