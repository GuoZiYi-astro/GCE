# %%
from NuPyCEE import sygma as s
import matplotlib.pyplot as plt

# %% [markdown]
# <font color=red size=4> I want to test the function of 'iniZ=-1.0, for the note in the chem_evol.py says it use non_default yield tables.

# %%
s1=s.sygma(iniZ=-1.0)
# Out:
# SYGMA run in progress..
#    SYGMA run completed - Run time: 0.06s

# %%
s2=s.sygma()
# Out:
# SYGMA run in progress..
#    SYGMA run completed - Run time: 0.03s

# %%
s1.plot_totmasses(fig=1,source='all',color='b')
s2.plot_totmasses(fig=1,source='all',color='r')

# %%
print(s1.nsmerger_table==s2.nsmerger_table)
# Out:
# True

# %%
print(s1.table==s2.table)
print(s1.sn1a_table==s2.sn1a_table)
# Out:
# True
# True

# %% [markdown]
# <font color=red size=4> it seems there are no difference in the yield tables they use in these two.

# %%
print(s1.exclude_masses==s2.exclude_masses)
# Out:
# True

# %%
print(s1.yield_interp==s2.yield_interp)
# Out:
# True

# %%
print(s1.total_ejecta_interp==s2.total_ejecta_interp)
# Out:
# True

# %%
print(s1.delayed_extra_yields_norm,s2.delayed_extra_yields_norm)
# Out:
# [] []

# %%
print(s1.iniZ)
# Out:
# -1.0

# %%
print(s1.zmetal)
# Out:
# 0.05795341846330504

# %%
print(s2.zmetal)
# Out:
# 0.05173116323311788

# %%
#s1.plot_massfrac(xaxis='age',yaxis='Z',color='b')
s2.plot_massfrac(xaxis='age',yaxis='Z',color='r')
plt.ylim(0.0001,0.15)
# Out:
# (0.0001, 0.15)

# %%
s1.plot_massfrac(xaxis='age',yaxis='Z',color='b')
#s2.plot_massfrac(xaxis='age',yaxis='Z',color='r')
plt.ylim(0.0001,0.15)
# Out:
# (0.0001, 0.15)

# %%
s1.plot_massfrac(xaxis='age',yaxis='Z',color='b')
s2.plot_massfrac(xaxis='age',yaxis='Z',color='r')
plt.ylim(0.0001,0.15)
# Out:
# (0.0001, 0.15)

# %% [markdown]
# iniZ do not affect the metallicity in ISM ?

# %%
s3=s.sygma(iniZ=0)
# Out:
# SYGMA run in progress..
#    SYGMA run completed - Run time: 0.03s

# %%
s1.plot_totmasses(source='all',color='b')
s3.plot_totmasses(source='all',color='r')
#plt.ylim(8e2,1e3)

# %%
s1.plot_totmasses(source='all',color='b')
s3.plot_totmasses(source='all',color='r')
plt.ylim(8e2,1e3)
# Out:
# (800.0, 1000.0)

# %%
s1.plot_totmasses(mass='stars',source='all',color='b')
s3.plot_totmasses(mass='stars',source='all',color='r')

# %%
print(s1.history.gas_mass[-1]==s3.history.gas_mass[-1])
# Out:
# True

# %% [markdown]
# <font color=red size=4> This print means that the final gas mass of the s1 and s3 is the same, that means from this part 'iniZ=-1'=='iniZ=0'.
#
# <font color=red size=4> The difference has not been found.

# %%
s4=s.sygma(iniZ=0.02)
# Out:
# SYGMA run in progress..
#    SYGMA run completed - Run time: 0.03s

# %%
s2.plot_totmasses(source='all',color='b')
s4.plot_totmasses(source='all',color='r')

# %% [markdown]
# <font color=red size=4> from this plot, the note of chem_evol.py is not right. The default of iniZ is 0.02.
