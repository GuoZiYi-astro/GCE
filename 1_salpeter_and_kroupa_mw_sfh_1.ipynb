# %%
from NuPyCEE import omega as o
from NuPyCEE import sygma as s
from matplotlib import pyplot as plt
import numpy as np

# %%
o1=o.omega(galaxy='milky_way',mgal=1.5e12,imf_type='kroupa')
o2=o.omega(galaxy='milky_way',mgal=1.5e12,imf_type='salpeter')
# Out:
# OMEGA run in progress..
#    OMEGA run completed - Run time: 0.79s
# OMEGA run in progress..
#    OMEGA run completed - Run time: 0.55s

# %% [markdown]
# ## SFH --- How the SFR change with the time (they should be the same for these two models)

# %%
o1.plot_star_formation_rate(label='Kroupa IMF')
o2.plot_star_formation_rate(label='Salpeter IMF')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/SFH.pdf',bbox_inches='tight')

# %% [markdown]
# ## The plot of some isotopic ratios

# %% [markdown]
# For plot_iso_ratio, the default solar abundance is from iniab2.0E-02GN93.ppn in yield_tables/iniabu.

# %%
y='C-12/C-13'
o1.plot_iso_ratio(yaxis=y,color='r',label='Kroupa IMF')
o2.plot_iso_ratio(yaxis=y,color='b',label='Salpeter IMF')
plt.title(y)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/C-12_C-13.pdf',bbox_inches='tight')
# Out:
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])

# %%
y='C-12/C-13'
o1.plot_iso_ratio(yaxis=y,color='r',label='Kroupa IMF')
o2.plot_iso_ratio(yaxis=y,color='b',label='Salpeter IMF')
plt.title(y)
plt.ylim(150,300)

y_ticks=np.arange(150,300,25)
plt.yticks(y_ticks)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/C-12_C-13_zoom.pdf',bbox_inches='tight')
# Out:
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])

# %%
y='O-16/O-18'
o1.plot_iso_ratio(yaxis=y,color='r',label='Kroupa IMF')
o2.plot_iso_ratio(yaxis=y,color='b',label='Salpeter IMF')
plt.title(y)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/O-16_O-18.pdf',bbox_inches='tight')
# Out:
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])

# %%
y='O-16/O-18'
o1.plot_iso_ratio(yaxis=y,color='r',label='Kroupa IMF')
o2.plot_iso_ratio(yaxis=y,color='b',label='Salpeter IMF')
plt.title(y)
plt.ylim(3e4,1.5e5)

plt.grid(which='minor')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/O-16_O-18_zoom.pdf',bbox_inches='tight')
# Out:
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])

# %%
y='O-16/O-17'
o1.plot_iso_ratio(yaxis=y,color='r',label='Kroupa IMF')
o2.plot_iso_ratio(yaxis=y,color='b',label='Salpeter IMF')
plt.title(y)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/O-16_O-17.pdf',bbox_inches='tight')
# Out:
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])

# %%
y='O-16/O-17'
o1.plot_iso_ratio(yaxis=y,color='r',label='Kroupa IMF')
o2.plot_iso_ratio(yaxis=y,color='b',label='Salpeter IMF')
plt.title(y)

y_ticks=np.arange(8000,15000,1000)
plt.yticks(y_ticks)
plt.ylim(8e3,1.5e4)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/O-16_O-17_zoom.pdf',bbox_inches='tight')
# Out:
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])
# /home/ziyi/PostGraduate/GCE/N3/NuPyCEE/omega.py:5224: RuntimeWarning: invalid value encountered in double_scalars
#   y.append(yields_evol[k][idy_1]/yields_evol[k][idy_2])

# %% [markdown]
# ## The plots of the evolution of some elements mass

# %%
e='O'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_mass(specie=e,return_x_y=True)
o2_x,o2_y=o2.plot_mass(specie=e,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# 687125391.8080165
# 465681083.1841593

# %%
e='O'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' zoom')
plt.ylim(1e8,1e9)
plt.xlim(5e8,2e10)
plt.grid(which='minor')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'zoom.pdf',bbox_inches='tight')

# %%
e='Mg'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_mass(specie=e,return_x_y=True)
o2_x,o2_y=o2.plot_mass(specie=e,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# 37159922.24166973
# 24568290.57662246

# %%
e='Mg'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' zoom')
plt.ylim(1e6,5e7)
plt.xlim(1e8,2e10)
plt.grid(which='minor')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'zoom.pdf',bbox_inches='tight')

# %%
e='Ca'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_mass(specie=e,return_x_y=True)
o2_x,o2_y=o2.plot_mass(specie=e,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# 5824714.584683469
# 4260877.47664073

# %%
e='Ca'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' zoom')
plt.ylim(5e5,1e7)
plt.xlim(5e8,2e10)
plt.grid(which='minor')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'zoom.pdf',bbox_inches='tight')

# %%
e='Ti'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_mass(specie=e,return_x_y=True)
o2_x,o2_y=o2.plot_mass(specie=e,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# 336337.95928205526
# 240879.77849040457

# %%
e='Ti'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' zoom')
plt.ylim(1e4,4e5)
plt.xlim(2e8,2e10)
plt.grid(which='minor')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'zoom.pdf',bbox_inches='tight')

# %%
e='Si'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_mass(specie=e,return_x_y=True)
o2_x,o2_y=o2.plot_mass(specie=e,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# 93325055.4603058
# 66254877.477404475

# %%
e='Si'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' zoom')
plt.ylim(1e7,1.5e8)
plt.xlim(8e8,2e10)
plt.grid(which='minor')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'zoom.pdf',bbox_inches='tight')

# %%
e='C'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_mass(specie=e,return_x_y=True)
o2_x,o2_y=o2.plot_mass(specie=e,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# 284464046.2558348
# 209806275.10305032

# %%
e='C'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' zoom')
plt.ylim(5e7,4e8)
plt.xlim(1e9,2e10)
plt.grid(which='minor')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'zoom.pdf',bbox_inches='tight')

# %%
e='N'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_mass(specie=e,return_x_y=True)
o2_x,o2_y=o2.plot_mass(specie=e,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# 16067880.080369694
# 11128115.414261011

# %%
e='N'
o1.plot_mass(specie=e,label='Kroupa IMF',color='r')
o2.plot_mass(specie=e,label='Salpeter IMF',color='b')
plt.title(e+' zoom')
plt.ylim(2e6,2e7)
plt.xlim(8e8,2e10)
plt.grid(which='minor')
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'zoom.pdf',bbox_inches='tight')

# %% [markdown]
# ## The plots of the evolution of the abundance of some elements

# %%
e='O'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_abun.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -1.334133751997857
# -1.5005664046689866

# %%
e='O'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-2,-1.2)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_abun_zoom.pdf',bbox_inches='tight')

# %%
e='Mg'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_abun.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -1.4928220123425247
# -1.6700071204050655

# %%
e='Mg'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-2.2,-1.25)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_abun_zoom.pdf',bbox_inches='tight')

# %%
e='Ca'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_abun.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -1.294969884368649
# -1.4282307392948446

# %%
e='Ca'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-2,-1.25)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_abun_zoom.pdf',bbox_inches='tight')

# %%
e='Ti'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_abun.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -1.2706577030546473
# -1.4131184962221672

# %%
e='Ti'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-1.8,-1.1)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_abun_zoom.pdf',bbox_inches='tight')

# %%
e='Si'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_abun.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -1.1257714860957053
# -1.2720371391047296

# %%
e='Si'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-1.8,-1)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_abun_zoom.pdf',bbox_inches='tight')

# %%
e='C'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_abun.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -1.272485520905033
# -1.4021796822489465

# %%
e='C'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-1.7,-1.2)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_abun_zoom.pdf',bbox_inches='tight')

# %%
e='N'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_abun.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -2.0072139859004205
# -2.1642361979552116

# %%
e='N'
abun='['+e+'/H]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-2.6,-1.9)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_abun_zoom.pdf',bbox_inches='tight')

# %% [markdown]
# ## The plot of the evolution of the ratio of some elements

# %%
e='O'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -0.19952154668403133
# -0.2831694121339703

# %%
e='O'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-0.35,-0.1)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe_zoom.pdf',bbox_inches='tight')

# %%
e='Mg'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -0.3582098070286992
# -0.45261012787004895

# %%
e='Mg'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-0.5,-0.3)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe_zoom.pdf',bbox_inches='tight')

# %%
e='Ca'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -0.16035767905482312
# -0.21083374675982802

# %%
e='Ca'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-0.24,-0.12)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe_zoom.pdf',bbox_inches='tight')

# %%
e='Ti'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# -0.13604549774082209
# -0.19572150368715047

# %%
e='Ti'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-0.22,-0)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe_zoom.pdf',bbox_inches='tight')

# %%
e='Si'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,return_x_y=True)
print(o1_y[-1])
print(o2_y[-1])
# Out:
# 0.008840719218120519
# -0.05464014656971328

# %%
e='Si'
abun='['+e+'/Fe]'
o1.plot_spectro(yaxis=abun,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,label='Salpeter IMF',color='b')
plt.title(abun+' zoom')
plt.ylim(-0.1,0.1)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe_zoom.pdf',bbox_inches='tight')

# %% [markdown]
# ## The plot of the evolution of the ratio of the elements with [Fe/H]

# %%
e='O'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe_Fe_H.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
print('final ratio of'+abun+':')
print(o1_y[-1])
print(o2_y[-1])
print('final ratio of [Fe/H]:')
print(o1_x[-1])
print(o2_x[-1])
# Out:
# final ratio of[O/Fe]:
# -0.19952154668403133
# -0.2831694121339703
# final ratio of [Fe/H]:
# -1.1346122053138257
# -1.2173969925350163

# %%
e='O'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x+' zoom')
plt.ylim(-0.4,0)
plt.xlim(-4,-1)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe_Fe_H_zoom.pdf',bbox_inches='tight')

# %%
e='Mg'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe_Fe_H.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
print('final ratio of'+abun+':')
print(o1_y[-1])
print(o2_y[-1])
print('final ratio of [Fe/H]:')
print(o1_x[-1])
print(o2_x[-1])
# Out:
# final ratio of[Mg/Fe]:
# -0.3582098070286992
# -0.45261012787004895
# final ratio of [Fe/H]:
# -1.1346122053138257
# -1.2173969925350163

# %%
e='Mg'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x+' zoom')
plt.ylim(-0.5,-0.2)
plt.xlim(-4,-1)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe_Fe_H_zoom.pdf',bbox_inches='tight')

# %%
e='Ca'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe_Fe_H.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
print('final ratio of'+abun+':')
print(o1_y[-1])
print(o2_y[-1])
print('final ratio of [Fe/H]:')
print(o1_x[-1])
print(o2_x[-1])
# Out:
# final ratio of[Ca/Fe]:
# -0.16035767905482312
# -0.21083374675982802
# final ratio of [Fe/H]:
# -1.1346122053138257
# -1.2173969925350163

# %%
e='Ca'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x+' zoom')
plt.ylim(-0.25,-0)
plt.xlim(-4,-1)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe_Fe_H_zoom.pdf',bbox_inches='tight')

# %%
e='Ti'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe_Fe_H.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
print('final ratio of'+abun+':')
print(o1_y[-1])
print(o2_y[-1])
print('final ratio of [Fe/H]:')
print(o1_x[-1])
print(o2_x[-1])
# Out:
# final ratio of[Ti/Fe]:
# -0.13604549774082209
# -0.19572150368715047
# final ratio of [Fe/H]:
# -1.1346122053138257
# -1.2173969925350163

# %%
e='Ti'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x+' zoom')
plt.ylim(-0.25,0.15)
plt.xlim(-8,-1)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe_Fe_H_zoom.pdf',bbox_inches='tight')

# %%
e='Si'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x)
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe_Fe_H.pdf',bbox_inches='tight')
o1_x,o1_y=o1.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
o2_x,o2_y=o2.plot_spectro(yaxis=abun,xaxis=x,return_x_y=True)
print('final ratio of'+abun+':')
print(o1_y[-1])
print(o2_y[-1])
print('final ratio of [Fe/H]:')
print(o1_x[-1])
print(o2_x[-1])
# Out:
# final ratio of[Si/Fe]:
# 0.008840719218120519
# -0.05464014656971328
# final ratio of [Fe/H]:
# -1.1346122053138257
# -1.2173969925350163

# %%
e='Si'
abun='['+e+'/Fe]'
x='[Fe/H]'
o1.plot_spectro(yaxis=abun,xaxis=x,label='Kroupa IMF',color='r')
o2.plot_spectro(yaxis=abun,xaxis=x,label='Salpeter IMF',color='b')
plt.title(abun+'-'+x+' zoom')
plt.ylim(-0.1,0.1)
plt.xlim(-4,-1)
plt.grid()
plt.savefig('/home/ziyi/PostGraduate/GCE/N3/1_salpeter_and_kroupa_mw_sfh/1-1/'+e+'_Fe_Fe_H_zoom.pdf',bbox_inches='tight')
