# %%
from NuPyCEE import omega as o

# %%
# The plot in omega
o1=o.omega(in_out_control=True,nb_1a_per_m=2.6e-03,transitionmass=11,mass_loading=6.0,in_out_ratio=1.70,mgal=8e6,iniZ=1e-4,tend=1e9)
o2=o.omega(DM_evolution=True,nb_1a_per_m=1.6e-3,transitionmass=10.3,mgal=1.4e6,f_dyn=4.8/0.095,exp_ml=3.3,iniZ=0.0001)
o3=o.omega(SF_law=True,nb_1a_per_m=1e-3,transitionmass=10.9,mass_loading=15.7,mgal=3.4e6,sfe=6.1,iniZ=0.0001)
# Out:
# OMEGA run in progress..
#    OMEGA run completed - Run time: 0.82s
# OMEGA run in progress..
#    OMEGA run completed - Run time: 0.62s
# OMEGA run in progress..
# ..Time refinement..
#    OMEGA run completed - Run time: 18.14s

# %%
o1.plot_spectro(xaxis='[Fe/H]',yaxis='[Si/Fe]')
o2.plot_spectro(xaxis='[Fe/H]',yaxis='[Si/Fe]',color='g')
o3.plot_spectro(xaxis='[Fe/H]',yaxis='[Si/Fe]',color='r')
